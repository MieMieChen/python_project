# %% [markdown]
# ## <span style="color: blue;">数据爬取（初学者尝试😩）</span>
#
# ### <span style="color: blue;">1.思路介绍</span>
# <p style="text-indent:2em;">本项目爬取的是 https://cn.tripadvisor.com 网页上关于上海市餐厅的一些数据，包括：名称、链接、评分、评价数、类别、人均（以￥表示）和地址。爬取的思路借鉴了 "<strong>下厨房</strong>" 的例子，总体思想为：先通过列表页爬取所有餐厅的名称和每个餐厅具体详情页的链接，然后再利用各餐厅的链接进一步访问餐厅的详情数据： 评分、评价数、类别、人均（以￥表示）和地址。</p>
#
# ### <span style="color: blue;">2.过程介绍</span>
# <p style="text-indent:2em;">然而，<strong><span style="color: blue;">想法很美好，现实很残酷😢</span></strong>，在一次次失败、IP被封的情况下，艰难的数据爬取过程主要可以分为以下三个阶段:</p>
#
# <p style="text-indent:2em;">
# <strong>第一阶段：</strong> 可称为“初次相遇”的<span style="color: red;">友好阶段</span>。在这个阶段，我们先进行一些简单的尝试，来判断爬取的可行性。期间我们多次尝试简单的数据爬取，仅用简单的请求头便可以快速方便地爬出第一页完整的名称数据，没有任何问题，导致我们误认为网页很友好。然后便快速加上了爬取其他数据的代码，为了以防万一还加了cookie，想当然的直接开始了100页（即3000家餐厅）数据的爬取。结果在爬到500家餐厅的时候喜提反爬大礼包，IP封禁一天。代码如下：
# </p>

# %%
import requests  # 用于发送 HTTP 请求
from lxml import etree  # 用于解析 HTML
import pandas as pd  # 用于数据处理与保存
import time  # 用于控制爬取时间间隔
import random  # 用于生成随机延时，防止被封禁
import re  # 用于正则表达式匹配

# 基础常量与请求头
BASE_URL = "https://cn.tripadvisor.com"  # TripAdvisor站点基础地址
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
                  '(KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',  # 浏览器标识
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',  # 接收内容类型
    'Accept-Language': 'zh-CN,zh;q=0.9',  # 接收语言
    'Referer': 'https://cn.tripadvisor.com/',  # 来源页
    'Connection': 'keep-alive',  # 长连接
    'Upgrade-Insecure-Requests': '1',  # 安全升级
    'Accept-Encoding': 'gzip, deflate, br',  # 支持压缩格式
}
# 添加 Cookie，替换为有效值以维持会话
headers['cookie'] = 'TAUnique=%1%enc%3AehA2qsyKuYqUNGugE4YEc9dm1eF7t820caB3EeCz%2FJ9SrUNk0jeLYY7X%2FAg52CqdNox8JbUSTxk%3D; TASameSite=1; TASSK=enc%3AAOmzUFPCpffK7LIMOwVntqBefMXOVXI6wkStaBdMhP54mY5qgcvBaHNeF5iZnow%2FsZp4VNaAPbB6FTDolTWcajp7mHRRXpMb7KMOK%2Bh458M9hoYUvNgAPeK2bav99uOsNg%3D%3D; TART=%1%enc%3AC3UfQ0LEIW3NF1z2d%2BxWDqFYetV%2BrK3dlfym18VuqiIy3iJHwE1LpO7n8YRMhaF8mCeVDBnC5k4%3D; TATrkConsent=eyJvdXQiOiJTT0NJQUxfTUVESUEiLCJpbiI6IkFEVixBTkEsRlVOQ1RJT05BTCJ9; _gcl_au=1.1.1498933911.1746629711; _ga=GA1.1.1573501834.1746629711; PMC=V2*MS.33*MD.20250507*LD.20250507; TATravelInfo=V2*A.2*MG.-1*HP.2*FL.3*RS.1; _lc2_fpi=b140173de591--01jtnkwnfyg257s5pzjgyewddd; _lc2_fpi_meta=%7B%22w%22%3A1746629711358%7D; pbjs_sharedId=0a51a26d-e85a-4512-b74b-3e9bab464466; pbjs_sharedId_cst=zix7LPQsHA%3D%3D; _lr_env_src_ats=false; _lr_sampling_rate=100; AMZN-Token=v2FweIB4SFZ1RnhTY1pNZ3dqZ0pUWnlxejVLNjBBdHhPVm5kV1NyNmtoUE43SThNY3VjVkM4ME51SkhKcy9UWG5rR3ZMT0Y2dW0yYUdUZ3FLbE9lMW82NnRVYmVQZEFMbXRuZTIwWHdIc2MxNDFUbjByQjhabDU1MVoyY0k0ckppK29ncWJrdgFiaXZ4IE1SQkg3Nys5RENZRjc3Kzk3Nys5VCsrL3ZlKy92UT09/w==; TAUD=LA-1746629711202-1*RDD-1-2025_05_07*LG-62979-2.1.F.*LD-62980-.....; pbjs_li_nonid=%7B%7D; pbjs_li_nonid_cst=zix7LPQsHA%3D%3D; pbjs_unifiedID=%7B%22TDID%22%3A%22460103ad-102a-418d-a466-288ac8ced98a%22%2C%22TDID_LOOKUP%22%3A%22TRUE%22%2C%22TDID_CREATED_AT%22%3A%222025-04-08T12%3A48%3A55%22%7D; pbjs_unifiedID_cst=zix7LPQsHA%3D%3D; TAAUTHEAT=ikOHzclO9G4Sxe01ABQC3I3IpT7XQpOMdOQw2Q027UVHaYyAwXyUTJx9huNbnp9__TBgEZl5WeJAiUo3socFYvUc066mAF2BbnROkCbl5gy4fWtqAvMCHYAAzd11L8dQSDFfnZYDgXAaQfyTgEiPv3z6Yzxkt0m8KRFQ9F6A4QWjfcmLkrXDKCYIdRqxBVriPJPVoTs2sD8TdbcaBEHhuXDoGauUqZwV7h4; TADCID=sR1Rl4y3l-byrqJLABQCJ4S5rDsRRMescG99HippfoVwdAn9TqGFFdpCvizh8nRIv8sJ8c-NzEeoB_Jah4SOKd0AzomZcGQS7RY; _li_dcdm_c=.tripadvisor.com; TASID=7FF9E722A1057A5FDD2CE407836EB7FE; PAC=AI-Y_UwuP7W9z2RhHDPFtJ0F5QGZDRS6MzayrTd_oqIVJIi_AG3BQtpNht2ohAAGpxVxsBwVaQea2gS3QcSc8PY6VZ61l2-31IqWr9ChSFNt-lTJYXbpcPkZ-aAWDtJtJUUIyR1Fl51auBOwIic95z-gxoGMYQdAMT9zdIXzAr6TSmD_yRNFZpFRizKg6qQvdSIJcOE9AkAY3esFEJiKGncZx2sqvh2VZE7B0N7rVKWr; _lr_retry_request=true; SRT=TART_SYNC; TASession=V2ID.7FF9E722A1057A5FDD2CE407836EB7FE*SQ.27*LS.FindRestaurants*HS.recommended*ES.popularity*DS.5*SAS.popularity*FPS.oldFirst*TS.144F5410E922E3B855ECB902400D4D9C*FA.1*DF.0*TRA.true; OptanonConsent=isGpcEnabled=0&datestamp=Fri+May+09+2025+16%3A33%3A21+GMT%2B0800+(%E4%B8%AD%E5%9B%BD%E6%A0%87%E5%87%86%E6%97%B6%E9%97%B4)&version=202405.2.0&browserGpcFlag=0&isIABGlobal=false&hosts=&consentId=144F5410E922E3B855ECB902400D4D9C&interactionCount=1&isAnonUser=1&landingPath=NotLandingPage&groups=C0001%3A1%2CC0003%3A1%2CSSPD_BG%3A1%2CC0004%3A1%2CC0002%3A1&AwaitingReconsent=false; _gcl_aw=GCL.1746779602.null; __gads=ID=3860aac49c1a1023:T=1746629716:RT=1746779601:S=ALNI_MbYaqBobsrmlfDdKTty6p9HmAUkXQ; __gpi=UID=000010b8d20c456a:T=1746629716:RT=1746779601:S=ALNI_Man7GEiGSfz4CbBR0Z5m2myvOv6Ig; __eoi=ID=0ecb8dd43c3a89f0:T=1746629716:RT=1746779602:S=AA-AfjbUuUTAiH0L37z1mAGUM5g0; _ga_QX0Q50ZC9P=GS2.1.s1746777027$o6$g1$t1746779610$j51$l0$h0; datadome=lI15Ea2XfCtGPKeKrC~tuWyqrAx6SlT6LNVH0pOH9q6RVogsnxBw0_mOj6OXpMv6ibWr2os6i5BSrgWL_FYxO5UxdmYVqZYdkYt4tgRXXto2Z2_DWfsunc_GLY9q2HZT; __vt=wmHuiTzM4bFEj0FUABQCT24E-H_BQo6gx1APGQJPtzVSDq_N0cSaiaKKBEwXyZzygz5CKQ-SSlXiW2hEvXE1tYjqsUxt_CQvB3FVVpLyrcJ6NUFqooCr0JcmXnTF_5e7Ri2CsngMgNxqIJYkc2uL9QG0HVY'  # TripAdvisor 返回的 Cookie


def fetch_list_pages(pages=1):
    """
    抓取餐厅列表页
    :param pages: 要抓取的页数，每页 30 条
    :return: 包含名称和详情链接的字典列表
    """
    restaurants = []  # 用于存储所有餐厅信息
    for page in range(pages):
        offset = page * 30  # 计算分页偏移量
        url = f"{BASE_URL}/FindRestaurants?geo=308272&offset={offset}&sort=FEATURED&broadened=false"  # 列表页 URL
        print(f"[列表] 爬第 {page+1} 页：{url}")  # 打印当前抓取页信息
        r = requests.get(url, headers=headers, timeout=15)  # 发送 GET 请求
        r.raise_for_status()  # 若状态码不是 200，则抛出异常
        tree = etree.HTML(r.text)  # 将返回的 HTML 文本解析成 etree
        
        # 通过 XPath 定位列表项 div
        divs = tree.xpath("//div[contains(@class,'mtnKn') and contains(@class,'ngXxk')]")
        for d in divs:
            raw = d.xpath("string(.)").strip()  # 提取节点文本并去除两端空白
            name = re.sub(r'^\d+\.\s*', '', raw)  # 去掉前缀序号
            href = d.xpath("ancestor::a[1]/@href")  # 向上查找最近的 a 标签链接
            if href:
                restaurants.append({
                    "名称": name,  # 餐厅名称
                    "链接": BASE_URL + href[0]  # 详情页完整 URL
                })
        # 随机睡眠 5~8 秒，防止请求过于频繁导致封禁
        time.sleep(5 + random.random() * 3)
    return restaurants  # 返回抓取到的餐厅列表


def fetch_detail(html_text):
    """
    从详情页 HTML 文本中提取信息
    :param html_text: 详情页的 HTML 字符串
    :return: 包含评分、评价数、类别、人均、地址等信息的字典
    """
    tree = etree.HTML(html_text)  # 解析 HTML
    detail = {}  # 存储解析结果
    
    # 提取评分（泡泡评分）
    rating = tree.xpath("//div[@data-automation='bubbleRatingValue']/text()")
    detail['评分'] = rating[0].strip() if rating else None  # 取第一个并去空，否则 None
    
    # 提取评价数，支持千分位格式
    reviews = tree.xpath("//div[@data-automation='bubbleReviewCount']//text()")
    if reviews:
        # 合并所有文本，并匹配数字及逗号
        m = re.search(r'([\d,]+)', "".join(reviews))
        detail['评价数'] = m.group(1).replace(',', '') if m else None  # 去掉逗号
    else:
        detail['评价数'] = None
    
    # 提取类别和人均消费
    items = tree.xpath("//span[contains(@class,'HUMGB') and contains(@class,'cPbcf')]//a/span/text()")
    if items:
        last = items[-1].strip()  # 取最后一个条目
        if '¥' in last:
            detail['人均'] = last  # 若包含人民币符号，则为人均消费
            # 类别为其余条目
            detail['类别'] = ",".join(i.strip() for i in items[:-1] if i.strip())
        else:
            detail['人均'] = None
            detail['类别'] = ",".join(i.strip() for i in items if i.strip())
    else:
        detail['人均'] = None
        detail['类别'] = None
    
    # 提取地址，尝试多种备选 XPath
    addr = tree.xpath("//span[@data-automation='restaurantsMapLinkOnName']/text()")
    if not addr:
        addr = tree.xpath("//button[@data-automation='restaurantsMapLinkOnName']//span/text()")
    detail['地址'] = addr[0].strip() if addr else None
    
    return detail  # 返回详情信息字典


def main():
    """
    主函数：先抓取列表页，再抓取详情页，最后保存为 CSV
    :return: 包含所有抓取数据的 DataFrame
    """
    # 1) 抓列表页（默认 100 页）
    lst = fetch_list_pages(pages=100)
    df_list = pd.DataFrame(lst)  # 转成 DataFrame 方便迭代

    # 2) 抓详情页
    records = []  # 存储所有详情记录
    for idx, row in df_list.iterrows():
        print(f"[详情] {idx+1}/{len(df_list)} {row['名称']}")  # 打印当前进度
        try:
            r = requests.get(row['链接'], headers=headers, timeout=15)  # 请求详情页
            r.raise_for_status()
            info = fetch_detail(r.text)  # 解析详情
        except Exception as e:
            print(f"  详情页失败：{e}")  # 出错时打印异常
            # 出错时构造空值
            info = {'评分': None, '评价数': None, '类别': None, '人均': None, '地址': None}
        # 合并名称与链接
        info.update({"名称": row['名称'], "链接": row['链接']})
        records.append(info)  # 加入记录列表
        # 随机睡眠 2~4 秒
        time.sleep(2 + random.random() * 2)
    
    # 3) 合并并保存为 CSV
    result = pd.DataFrame(records, columns=['名称','链接','评分','评价数','类别','人均','地址'])
    result.to_csv("tripadvisor_shanghai.csv", index=False, encoding="utf-8-sig")  # 保存文件
    print("已保存到 tripadvisor_shanghai.csv，共抓取条数：", len(result))
    return result
df = main()
# Out:
# [列表] 爬第 1 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=0&sort=FEATURED&broadened=false
# [列表] 爬第 2 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=30&sort=FEATURED&broadened=false
# [列表] 爬第 3 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=60&sort=FEATURED&broadened=false
# [列表] 爬第 4 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=90&sort=FEATURED&broadened=false
# [列表] 爬第 5 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=120&sort=FEATURED&broadened=false
# [列表] 爬第 6 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=150&sort=FEATURED&broadened=false
# [列表] 爬第 7 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=180&sort=FEATURED&broadened=false
# [列表] 爬第 8 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=210&sort=FEATURED&broadened=false
# [列表] 爬第 9 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=240&sort=FEATURED&broadened=false
# [列表] 爬第 10 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=270&sort=FEATURED&broadened=false
# [列表] 爬第 11 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=300&sort=FEATURED&broadened=false
# [列表] 爬第 12 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=330&sort=FEATURED&broadened=false
# [列表] 爬第 13 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=360&sort=FEATURED&broadened=false
# [列表] 爬第 14 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=390&sort=FEATURED&broadened=false
# [列表] 爬第 15 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=420&sort=FEATURED&broadened=false
# [列表] 爬第 16 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=450&sort=FEATURED&broadened=false
# [列表] 爬第 17 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=480&sort=FEATURED&broadened=false
# [列表] 爬第 18 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=510&sort=FEATURED&broadened=false
# [列表] 爬第 19 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=540&sort=FEATURED&broadened=false
# [列表] 爬第 20 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=570&sort=FEATURED&broadened=false
# [列表] 爬第 21 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=600&sort=FEATURED&broadened=false
# [列表] 爬第 22 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=630&sort=FEATURED&broadened=false
# [列表] 爬第 23 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=660&sort=FEATURED&broadened=false
# [列表] 爬第 24 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=690&sort=FEATURED&broadened=false
# [列表] 爬第 25 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=720&sort=FEATURED&broadened=false
# [列表] 爬第 26 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=750&sort=FEATURED&broadened=false
# [列表] 爬第 27 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=780&sort=FEATURED&broadened=false
# [列表] 爬第 28 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=810&sort=FEATURED&broadened=false
# [列表] 爬第 29 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=840&sort=FEATURED&broadened=false
# [列表] 爬第 30 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=870&sort=FEATURED&broadened=false
# [列表] 爬第 31 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=900&sort=FEATURED&broadened=false
# [列表] 爬第 32 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=930&sort=FEATURED&broadened=false
# [列表] 爬第 33 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=960&sort=FEATURED&broadened=false
# [列表] 爬第 34 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=990&sort=FEATURED&broadened=false
# [列表] 爬第 35 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1020&sort=FEATURED&broadened=false
# [列表] 爬第 36 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1050&sort=FEATURED&broadened=false
# [列表] 爬第 37 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1080&sort=FEATURED&broadened=false
# [列表] 爬第 38 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1110&sort=FEATURED&broadened=false
# [列表] 爬第 39 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1140&sort=FEATURED&broadened=false
# [列表] 爬第 40 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1170&sort=FEATURED&broadened=false
# [列表] 爬第 41 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1200&sort=FEATURED&broadened=false
# [列表] 爬第 42 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1230&sort=FEATURED&broadened=false
# [列表] 爬第 43 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1260&sort=FEATURED&broadened=false
# [列表] 爬第 44 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1290&sort=FEATURED&broadened=false
# [列表] 爬第 45 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1320&sort=FEATURED&broadened=false
# [列表] 爬第 46 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1350&sort=FEATURED&broadened=false
# [列表] 爬第 47 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1380&sort=FEATURED&broadened=false
# [列表] 爬第 48 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1410&sort=FEATURED&broadened=false
# [列表] 爬第 49 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1440&sort=FEATURED&broadened=false
# [列表] 爬第 50 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1470&sort=FEATURED&broadened=false
# [列表] 爬第 51 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1500&sort=FEATURED&broadened=false
# [列表] 爬第 52 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1530&sort=FEATURED&broadened=false
# [列表] 爬第 53 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1560&sort=FEATURED&broadened=false
# [列表] 爬第 54 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1590&sort=FEATURED&broadened=false
# [列表] 爬第 55 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1620&sort=FEATURED&broadened=false
# [列表] 爬第 56 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1650&sort=FEATURED&broadened=false
# [列表] 爬第 57 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1680&sort=FEATURED&broadened=false
# [列表] 爬第 58 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1710&sort=FEATURED&broadened=false
# [列表] 爬第 59 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1740&sort=FEATURED&broadened=false
# [列表] 爬第 60 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1770&sort=FEATURED&broadened=false
# [列表] 爬第 61 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1800&sort=FEATURED&broadened=false
# [列表] 爬第 62 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1830&sort=FEATURED&broadened=false
# [列表] 爬第 63 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1860&sort=FEATURED&broadened=false
# [列表] 爬第 64 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1890&sort=FEATURED&broadened=false
# [列表] 爬第 65 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1920&sort=FEATURED&broadened=false
# [列表] 爬第 66 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1950&sort=FEATURED&broadened=false
# [列表] 爬第 67 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=1980&sort=FEATURED&broadened=false
# [列表] 爬第 68 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2010&sort=FEATURED&broadened=false
# [列表] 爬第 69 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2040&sort=FEATURED&broadened=false
# [列表] 爬第 70 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2070&sort=FEATURED&broadened=false
# [列表] 爬第 71 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2100&sort=FEATURED&broadened=false
# [列表] 爬第 72 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2130&sort=FEATURED&broadened=false
# [列表] 爬第 73 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2160&sort=FEATURED&broadened=false
# [列表] 爬第 74 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2190&sort=FEATURED&broadened=false
# [列表] 爬第 75 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2220&sort=FEATURED&broadened=false
# [列表] 爬第 76 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2250&sort=FEATURED&broadened=false
# [列表] 爬第 77 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2280&sort=FEATURED&broadened=false
# [列表] 爬第 78 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2310&sort=FEATURED&broadened=false
# [列表] 爬第 79 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2340&sort=FEATURED&broadened=false
# [列表] 爬第 80 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2370&sort=FEATURED&broadened=false
# [列表] 爬第 81 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2400&sort=FEATURED&broadened=false
# [列表] 爬第 82 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2430&sort=FEATURED&broadened=false
# [列表] 爬第 83 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2460&sort=FEATURED&broadened=false
# [列表] 爬第 84 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2490&sort=FEATURED&broadened=false
# [列表] 爬第 85 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2520&sort=FEATURED&broadened=false
# [列表] 爬第 86 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2550&sort=FEATURED&broadened=false
# [列表] 爬第 87 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2580&sort=FEATURED&broadened=false
# [列表] 爬第 88 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2610&sort=FEATURED&broadened=false
# [列表] 爬第 89 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2640&sort=FEATURED&broadened=false
# [列表] 爬第 90 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2670&sort=FEATURED&broadened=false
# [列表] 爬第 91 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2700&sort=FEATURED&broadened=false
# [列表] 爬第 92 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2730&sort=FEATURED&broadened=false
# [列表] 爬第 93 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2760&sort=FEATURED&broadened=false
# [列表] 爬第 94 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2790&sort=FEATURED&broadened=false
# [列表] 爬第 95 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2820&sort=FEATURED&broadened=false
# [列表] 爬第 96 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2850&sort=FEATURED&broadened=false
# [列表] 爬第 97 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2880&sort=FEATURED&broadened=false
# [列表] 爬第 98 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2910&sort=FEATURED&broadened=false
# [列表] 爬第 99 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2940&sort=FEATURED&broadened=false
# [列表] 爬第 100 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=2970&sort=FEATURED&broadened=false
# [详情] 1/3000 上海佳家汤包(黄河路店)
# [详情] 2/3000 ROOF (The Shanghai EDITION)
# [详情] 3/3000 小杨生煎馆(吴江路店)
# [详情] 4/3000 星巴克臻选上海烘焙工坊
# [详情] 5/3000 上海小杨生煎(黄河路店)
# [详情] 6/3000 金轩(上海浦东丽思卡尔顿酒店)
# [详情] 7/3000 莉莲蛋挞(四季坊店)
# [详情] 8/3000 小杨生煎(宁波路店)
# [详情] 9/3000 芝乐坊餐厅
# [详情] 10/3000 怡咖啡
# [详情] 11/3000 Flair Rooftop
# [详情] 12/3000 Yone餐厅酒吧 (上海艾迪逊酒店)
# [详情] 13/3000 上海姥姥
# [详情] 14/3000 上海夜上海(新天地太平湖店)
# [详情] 15/3000 上海香溢培客(安福路店)
# [详情] 16/3000 WET® 泳池酒吧
# [详情] 17/3000 Scena di Angelo 意大利餐厅
# [详情] 18/3000 The Fellas
# [详情] 19/3000 花马天堂云南餐厅(外滩店)
# [详情] 20/3000 Hakkasan
# [详情] 21/3000 两咖啡
# [详情] 22/3000 新大陆中国厨房
# [详情] 23/3000 宝莱坞印度餐厅
# [详情] 24/3000 Aura酒廊及爵士酒吧(上海浦东丽思卡尔顿酒店)
# [详情] 25/3000 Goodfellas意大利餐厅
# [详情] 26/3000 The Captain
# [详情] 27/3000 味香斋(雁荡路店)
# [详情] 28/3000 Bella Napoli(南汇路店)
# [详情] 29/3000 外婆家(南京西路店分店)
# [详情] 30/3000 大蒜土耳其餐厅
# [详情] 31/3000 上海世纪100餐厅(上海柏悦酒店)
# [详情] 32/3000 Roof 325
# [详情] 33/3000 Vedas 印度餐厅(常熟路店)
# [详情] 34/3000 耶里夏丽新疆餐厅(南京东路店)
# [详情] 35/3000 老吉士酒家(天平路店)
# [详情] 36/3000 帕夏土耳其餐厅
# [详情] 37/3000 RAW Eatery And Wood Grill
# [详情] 38/3000 镜花水月
# [详情] 39/3000 Mr & Mrs Bund - French Seafood-Steak House by Paul Pairet
# [详情] 40/3000 塔金摩洛哥餐厅
# [详情] 41/3000 Shanghai Tavern (The Shanghai EDITION)
# [详情] 42/3000 Cages Bar and Sports
# [详情] 43/3000 成隆行蟹王府
# [详情] 44/3000 富春小笼(愚园路店)
# [详情] 45/3000 蓝蛙(环球金融中心店)
# [详情] 46/3000 鼎泰丰(环球金融中心店)
# [详情] 47/3000 耶里夏丽(东方店)
# [详情] 48/3000 沈大成(南京东路店)
# [详情] 49/3000 夏宫
# [详情] 50/3000 Palatino Roman Cuisine
# [详情] 51/3000 莫尔顿牛排坊
# [详情] 52/3000 龙凤厅
# [详情] 53/3000 POP露台餐厅与酒吧
# [详情] 54/3000 Polux by Paul Pairet
# [详情] 55/3000 7 Yakitori Bistro
# [详情] 56/3000 Long Bar 廊吧 （上海外滩华尔道夫酒店）
# [详情] 57/3000 Zeitgeist
# [详情] 58/3000 The COOK•厨
# [详情] 59/3000 BREAD etc.
# [详情] 60/3000 Takumi Robata & 清酒酒吧
# [详情] 61/3000 le Comptoir de Pierre Gagnaire
# [详情] 62/3000 Al Borgo
# [详情] 63/3000 久久滴水洞(茂名南路店)
# [详情] 64/3000 尚牛社会（上海商城）
# [详情] 65/3000 龙门阵茶屋川菜馆
# [详情] 66/3000 上海绿波廊(豫园路店)
# [详情] 67/3000 The MEAT∙扒-浦东嘉里大酒店
# [详情] 68/3000 The Nest
# [详情] 69/3000 泰廊
# [详情] 70/3000 罗斯福公馆
# [详情] 71/3000 咖啡苑
# [详情] 72/3000 Calypso地中海餐厅
# [详情] 73/3000 上海香料艺术印度餐厅（大沽路店）
# [详情] 74/3000 1515牛排馆•酒吧
# [详情] 75/3000 艾菲斯餐厅土耳其&地中海美食
# [详情] 76/3000 新荣记(上海广场店)
# [详情] 77/3000 里维埃拉松鹤楼(外滩店)
# [详情] 78/3000 鼎泰丰(上海新天地店)
# [详情] 79/3000 外婆家
# [详情] 80/3000 标帜餐厅 (上海外滩W酒店)
# [详情] 81/3000 御宝轩
# [详情] 82/3000 Eli Falafel
# [详情] 83/3000 全聚德(浦东店)
# [详情] 84/3000 Speak Low
# [详情] 85/3000 芭芭露莎
# [详情] 86/3000 Da Ivo 意大利魔镜餐厅
# [详情] 87/3000 古铜法式餐厅
# [详情] 88/3000 Tsuru
# [详情] 89/3000 大董海参店(环贸iapm店)
# [详情] 90/3000 舞台餐厅
# [详情] 91/3000 浦江汇
# [详情] 92/3000 孔乙己酒家
# [详情] 93/3000 Bella Napoli(长乐路店)
# [详情] 94/3000 福1088
# [详情] 95/3000 上海翡翠酒家(新天地店)
# [详情] 96/3000 MESS Gallery Restaurant & Bar
# [详情] 97/3000 东方明珠旋转餐厅
# [详情] 98/3000 ElWilly
# [详情] 99/3000 8 1/2 Otto e Mezzo BOMBANA
# [详情] 100/3000 人和馆
# [详情] 101/3000 The Commune Social
# [详情] 102/3000 沃歌斯(淮海路店)
# [详情] 103/3000 上海海底捞火锅店(张杨路店)
# [详情] 104/3000 百味园
# [详情] 105/3000 Mercato by Jean-Georges
# [详情] 106/3000 雍颐庭
# [详情] 107/3000 Ginger by the Park - Bistro & Bar
# [详情] 108/3000 El Bodegón
# [详情] 109/3000 Ultraviolet by Paul Pairet
# [详情] 110/3000 Hai Di Lao Hot Pot Restaurant
# [详情] 111/3000 丽笙星空酒吧
# [详情] 112/3000 华懋阁
# [详情] 113/3000 Captain Bar
# [详情] 114/3000 拉蒂娜·巴西牛排馆（陆家嘴店）
# [详情] 115/3000 茹丝葵牛排馆
# [详情] 116/3000 锡伯新疆餐厅
# [详情] 117/3000 九重天酒廊 (上海金茂君悦大酒店)
# [详情] 118/3000 南翔馒头店(南京西路)
# [详情] 119/3000 Tandoor Indian Restaurant
# [详情] 120/3000 恰餐厅与酒吧
# [详情] 121/3000 La Parisienne
# [详情] 122/3000 Mayita
# [详情] 123/3000 上海大马可意大利餐厅(旗舰店)
# [详情] 124/3000 Indian Masala Restaurant
# [详情] 125/3000 旋景餐厅
# [详情] 126/3000 新白鹿餐厅(南京东路店)
# [详情] 127/3000 翡翠36餐厅
# [详情] 128/3000 蔚景阁中餐厅
# [详情] 129/3000 福和慧
# [详情] 130/3000 Fat Cow
# [详情] 131/3000 喜粤8号
# [详情] 132/3000 Victor's Cafe
# [详情] 133/3000 毛豆阿姨
# [详情] 134/3000 茉莉酒廊
# [详情] 135/3000 上海老饭店
# [详情] 136/3000 EGG cafe
# [详情] 137/3000 塔可贝尔(陆家嘴店)
# [详情] 138/3000 三号黄浦会 Canton Table
# [详情] 139/3000 Bistrot 321 le Bec
# [详情] 140/3000 莱莱小吃
# [详情] 141/3000 上海滩餐厅(新天地店)
# [详情] 142/3000 Linlongfang Xiaolongbao (Jianguo East Road)
# [详情] 143/3000 Shanghai First Foodhall
# [详情] 144/3000 梅龙镇酒家(总店)
# [详情] 145/3000 Estado Puro Shanghai
# [详情] 146/3000 拉蒂娜·巴西牛排馆（铜仁路店）
# [详情] 147/3000 L'ATELIER de Joël Robuchon
# [详情] 148/3000 The BREW 酿
# [详情] 149/3000 Traditional Beijing Roast Duck Restaurant
# [详情] 150/3000 JW's加州扒房 (上海明天广场JW万豪酒店)
# [详情] 151/3000 The Refinery
# [详情] 152/3000 Sheng Yong Xing Peking Duck Restaurant
# [详情] 153/3000 天都里印度餐厅(茂名南路店)
# [详情] 154/3000 齐民市集(上海芮欧店)
# [详情] 155/3000 上海老站(漕溪北路店)
# [详情] 156/3000 丽嘉阁 The Ritz Bar & Lounge
# [详情] 157/3000 COLCA 秘鲁西班牙餐厅
# [详情] 158/3000 Bao Li Xuan
# [详情] 159/3000 Din Tai Fung
# [详情] 160/3000 Boteco
# [详情] 161/3000 波特曼餐厅
# [详情] 162/3000 好戏连台
# [详情] 163/3000 山里日本料理 (茂名南路店)
# [详情] 164/3000 WOOBAR酒吧
# [详情] 165/3000 上海Boxing Cat Brewery(复兴西路店)
# [详情] 166/3000 Cafe Del Volcan
# [详情] 167/3000 吉士酒家
# [详情] 168/3000 金茂君悦咖啡厅
# [详情] 169/3000 Jean-Georges
# [详情] 170/3000 艾利爵士餐廳
# [详情] 171/3000 Tomatito
# [详情] 172/3000 上海宝莱纳餐厅(新天地店)
# [详情] 173/3000 Ministry Of Crab
# [详情] 174/3000 Club Room (The Shanghai EDITION)
# [详情] 175/3000 爵士酒吧
# [详情] 176/3000 Green & Safe
# [详情] 177/3000 Lumiere's Kitchen
# [详情] 178/3000 上海功德林(南京西路店)
# [详情] 179/3000 Jade Garden
# [详情] 180/3000 CASANOVA意大利餐厅
# [详情] 181/3000 House of Blues & Jazz
# [详情] 182/3000 肯德基(浦东机场一店)
# [详情] 183/3000 azul Tapas Lounge
# [详情] 184/3000 Shake Shack
# [详情] 185/3000 大蔬无界·上海外滩和美馆
# [详情] 186/3000 玛雅 (四方新城店)
# [详情] 187/3000 建国328小馆
# [详情] 188/3000 圆苑酒家(兴国路店)
# [详情] 189/3000 泰安门
# [详情] 190/3000 航迹厨房(上海鲁能JW万豪侯爵酒店)
# [详情] 191/3000 VANCA'S凡客极品
# [详情] 192/3000 本家韩国料理(吴中路店)
# [详情] 193/3000 新肴珍宝海鲜(ifc店)
# [详情] 194/3000 大壶春(浦东总店)
# [详情] 195/3000 桂花楼
# [详情] 196/3000 悦轩
# [详情] 197/3000 The Bund Tea Company
# [详情] 198/3000 Epices & Foie Gras
# [详情] 199/3000 奇利斯餐厅及酒吧
# [详情] 200/3000 Bottega (kwah Store)
# [详情] 201/3000 瑞福园酒家(茂名南路店)
# [详情] 202/3000 鼎王无老锅(上海无老衡山店)
# [详情] 203/3000 Bar Level 87 at Park Hyatt Shanghai
# [详情] 204/3000 PHÉNIX
# [详情] 205/3000 MAKAN Restaurant
# [详情] 206/3000 申报馆咖啡
# [详情] 207/3000 汗巴巴巴基斯坦餐厅
# [详情] 208/3000 王宝和酒家(黄浦店)
# [详情] 209/3000 RAC Coffee
# [详情] 210/3000 汉舍中国菜馆(丁香路店)
# [详情] 211/3000 VEDAS印度餐厅(虹桥店)
# [详情] 212/3000 骆驼餐吧
# [详情] 213/3000 莱美露滋
# [详情] 214/3000 Cejerdary (The Bund)
# [详情] 215/3000 BICE Restaurant 意大利餐厅
# [详情] 216/3000 鹅岛精酿啤酒餐厅
# [详情] 217/3000 小南国
# [详情] 218/3000 云之缘(定西路店)
# [详情] 219/3000 Bottega (jing'an)
# [详情] 220/3000 丰汇唐韵茶楼
# [详情] 221/3000 The Beer Lady (Suzhou Creek)
# [详情] 222/3000 Mammamia意大利餐厅 (巨鹿路)
# [详情] 223/3000 南麓.浙里
# [详情] 224/3000 晶采轩(芮欧百货店)
# [详情] 225/3000 Bastard
# [详情] 226/3000 Seesaw Coffee(愚园路店)
# [详情] 227/3000 一仟一夜(常熟路店)
# [详情] 228/3000 勃逊
# [详情] 229/3000 The Flying Fox Irish Bistro
# [详情] 230/3000 外婆家(大悦城店)
# [详情] 231/3000 Yugo Grill
# [详情] 232/3000 Shanghai Brew House(虹梅路店)
# [详情] 233/3000 O’mills Sourdough Bakery&bistro
# [详情] 234/3000 海底捞火锅 (第一百货)
# [详情] 235/3000 58° 扒房
# [详情] 236/3000 福1039
# [详情] 237/3000 Texas Roadhouse
# [详情] 238/3000 1886汽车主题德国餐厅(外滩店)
# [详情] 239/3000 Duli度粒
# [详情] 240/3000 Mint Club
# [详情] 241/3000 凯乐文地中海餐厅
# [详情] 242/3000 米罗斯希腊餐厅(岳阳路店)
# [详情] 243/3000 巴国布衣 (浦东店)
# [详情] 244/3000 Baker&Spice(K11店)
# [详情] 245/3000 Da Vittorio Shanghai
# [详情] 246/3000 Coquille Seafood Bistro
# [详情] 247/3000 大董海参店(上海越洋广场店)
# [详情] 248/3000 耶里夏丽(正大广场店)
# [详情] 249/3000 Cotton's(新华路店)
# [详情] 250/3000 食庐(浦东嘉里城店)
# [详情] 251/3000 酒吞一馆
# [详情] 252/3000 Le Saleya(长乐路店)
# [详情] 253/3000 上海德兴面馆(广东路总店)
# [详情] 254/3000 Lao Beijing Restaurant
# [详情] 255/3000 金茂俱乐部上海餐厅
# [详情] 256/3000 THE Cannery
# [详情] 257/3000 OPUS Lounge
# [详情] 258/3000 捞王锅物料理(静安店)
# [详情] 259/3000 查餐厅(思南路店)
# [详情] 260/3000 Red Salt Indian Pakistani Restaurant
# [详情] 261/3000 青鹤谷(虹莘路总店)
# [详情] 262/3000 光明邨大酒家(淮海中路总店)
# [详情] 263/3000 米泰
# [详情] 264/3000 Roof Garden (The Shanghai EDITION)
# [详情] 265/3000 华美达大酒店中餐厅
# [详情] 266/3000 法式薄饼店La Creperie
# [详情] 267/3000 Tairyo Teppanyaki
# [详情] 268/3000 SunFlour(安福路店)
# [详情] 269/3000 The Blarney Stone Irish Pub Yong Kang Road
# [详情] 270/3000 旋宫50海神诺富特旋转餐厅
# [详情] 271/3000 秀 (上海静安瑞吉酒店)
# [详情] 272/3000 狮
# [详情] 273/3000 Shanghai Min
# [详情] 274/3000 帕戈意大利餐厅
# [详情] 275/3000 CYCLO(158坊店)
# [详情] 276/3000 万寿斋
# [详情] 277/3000 上海海底捞火锅店(北京西路店)
# [详情] 278/3000 CHEZ JOJO (Yongjia Road)
# [详情] 279/3000 椰香天堂泰国料理
# [详情] 280/3000 全聚德(闸北店)
# [详情] 281/3000 云海肴云南菜(新天地店)
# [详情] 282/3000 蘇小柳点心专门店
# [详情] 283/3000 Alimentari
# [详情] 284/3000 Flying Elephant Restaurant
# [详情] 285/3000 星巴克(浦东机场T2到达店)
# [详情] 286/3000 桃园眷村(静安寺店)
# [详情] 287/3000 The White Horse
# [详情] 288/3000 Hit Wicket Indian Cuisine & Bar
# [详情] 289/3000 上海咖啡树(武康路店)
# [详情] 290/3000 MR PANCAKE House(武定路店)
# [详情] 291/3000 利苑
# [详情] 292/3000 言盐西餐厅
# [详情] 293/3000 上海1号私藏菜(静安寺店)
# [详情] 294/3000 荣小馆
# [详情] 295/3000 Urban Thai
# [详情] 296/3000 南京大牌档(中山公园龙之梦店)
# [详情] 297/3000 Papito pancakes
# [详情] 298/3000 M1NT
# [详情] 299/3000 海底捞火锅店(打浦路店)
# [详情] 300/3000 Judy's
# [详情] 301/3000 王家沙点心店(南京西路总店)
# [详情] 302/3000 上海老北京前门烤鸭(外滩店)
# [详情] 303/3000 1221餐馆
# [详情] 304/3000 Scarpetta
# [详情] 305/3000 D.O.C Gastronomia Italiana
# [详情] 306/3000 鼎泰丰(嘉里店)
# [详情] 307/3000 麦当劳(南京东路店)
# [详情] 308/3000 印度咖喱小屋
# [详情] 309/3000 万豪轩中餐厅
# [详情] 310/3000 丹
# [详情] 311/3000 Frasca
# [详情] 312/3000 逸龙阁中餐厅半岛酒店
# [详情] 313/3000 哈根达斯（南京东路店）
# [详情] 314/3000 Bella Vita
# [详情] 315/3000 沃夫冈牛排馆
# [详情] 316/3000 Barbarian On The Bund Sinar Mas Plaza
# [详情] 317/3000 Green&Safe(新天地店)
# [详情] 318/3000 Long Bar
# [详情] 319/3000 可口可乐欢乐餐厅
# [详情] 320/3000 Liquid Laundry
# [详情] 321/3000 新光酒家方亮蟹宴(黄浦店)
# [详情] 322/3000 The Shed
# [详情] 323/3000 Porto Matto Italian Restaurant
# [详情] 324/3000 Sober Company
# [详情] 325/3000 Mosaic 莫赛克
# [详情] 326/3000 TUK土耳其餐厅(淮海中路店)
# [详情] 327/3000 扬州饭店(黄浦店)
# [详情] 328/3000 佳家汤包(丽园路店)
# [详情] 329/3000 乐意坊意大利手工披萨(陆家嘴店)
# [详情] 330/3000 琳怡
# [详情] 331/3000 Alimentari Mulino
# [详情] 332/3000 大味鳗
# [详情] 333/3000 夏蕾餐厅.酒吧
# [详情] 334/3000 Central Perk
# [详情] 335/3000 弦月窗
# [详情] 336/3000 Fiama Italian Mediterranean Teppan Grill
# [详情] 337/3000 Maki House
# [详情] 338/3000 小南国(正大广场店)
# [详情] 339/3000 福1015
# [详情] 340/3000 La Barra Shanghai
# [详情] 341/3000 火烈鸟精酿啤酒餐吧
# [详情] 342/3000 彩丰楼
# [详情] 343/3000 Shari Modern Japanese cuisine
# [详情] 344/3000 金茂君悦美式烧烤
# [详情] 345/3000 Barbarian
# [详情] 346/3000 遇外滩
# [详情] 347/3000 万豪咖啡厅(上海明天广场JW万豪酒店)
# [详情] 348/3000 慕光日本料理(Hikari)
# [详情] 349/3000 Highline
# [详情] 350/3000 小南国(海宁路店)
# [详情] 351/3000 In Elephant Indian Restaurant
# [详情] 352/3000 Must Grill
# [详情] 353/3000 Wolfgang Puck Bar & Grill
# [详情] 354/3000 海底捞火锅长寿路店(上海五店)
# [详情] 355/3000 王宝和大酒店
# [详情] 356/3000 Jamaica Blue(九江路店)
# [详情] 357/3000 南翔馒头店
# [详情] 358/3000 Nepali Kitchen
# [详情] 359/3000 金茂俱乐部上海餐厅
# [详情] 360/3000 Dakshin Indian Cuisine
# [详情] 361/3000 Saigon Mama
# [详情] 362/3000 Boom Boom Bagels
# [详情] 363/3000 江畔-上海外滩英迪格酒店
# [详情] 364/3000 鲜得来排骨年糕(云南南路店)
# [详情] 365/3000 Eli Falafel (fucheng Road)
# [详情] 366/3000 El Bodegon阿根廷秘鲁餐厅(番禺路店)
# [详情] 367/3000 上海会馆(香港名都店)
# [详情] 368/3000 小杨生煎(陕西北路店)
# [详情] 369/3000 艾比之路
# [详情] 370/3000 银平(仙霞路店)
# [详情] 371/3000 兰心餐厅
# [详情] 372/3000 米赫曼新疆风味餐厅
# [详情] 373/3000 南麓.浙里(巨鹿店)
# [详情] 374/3000 上海浦东丽晶酒店Camelia
# [详情] 375/3000 Shook!
# [详情] 376/3000 上海杏花楼(福州路总店)
# [详情] 377/3000 很久以前只是家串店(云南南路店)
# [详情] 378/3000 老吉士酒家(环贸店)
# [详情] 379/3000 Kathleen’s Bistro
# [详情] 380/3000 Sumerian
# [详情] 381/3000 萤七人间
# [详情] 382/3000 莱莱小笼 - 静安店
# [详情] 383/3000 锅德港式海鲜肥牛火锅(新天地南里店)
# [详情] 384/3000 上海 101
# [详情] 385/3000 巴国布衣(虹桥店)
# [详情] 386/3000 重庆高老九火锅(人民广场店)
# [详情] 387/3000 唐阁
# [详情] 388/3000 松月楼
# [详情] 389/3000 泰康汤包馆
# [详情] 390/3000 上海新旺茶餐厅(汉口路店)
# [详情] 391/3000 申德勒加油站西餐厅
# [详情] 392/3000 滨江一号
# [详情] 393/3000 宜客乐-大宁福朋喜来登酒店
# [详情] 394/3000 南京大牌档(人民广场世茂店)
# [详情] 395/3000 合点寿司(96广场店)
# [详情] 396/3000 宝格丽酒吧
# [详情] 397/3000 哈贝贝
# [详情] 398/3000 Saizeriya Ristorante E Caffe
# [详情] 399/3000 兰亭餐厅
# [详情] 400/3000 Charbon by Paul Pairet
# [详情] 401/3000 Mr Su Seafood
# [详情] 402/3000 La Creperie (Tao Jiang)
# [详情] 403/3000 Lao Zheng Xing Restaurant
# [详情] 404/3000 Co.Cheese Melt Bar
# [详情] 405/3000 Efes Restaurant Turkish & Mediterraean Cuisine Puxi Branch
# [详情] 406/3000 Mercado 505
# [详情] 407/3000 派社
# [详情] 408/3000 Indian Kitchen
# [详情] 409/3000 Sproutworks(新天地店)
# [详情] 410/3000 Aurora Restaurant, Disneyland Hotel
# [详情] 411/3000 FLINT扒房 (上海鲁能JW万豪侯爵酒店)
# [详情] 412/3000 Ippudo
# [详情] 413/3000 大壶春
# [详情] 414/3000 宝莱纳餐厅滨江店
# [详情] 415/3000 JW酒廊 (上海鲁能JW万豪侯爵酒店)
# [详情] 416/3000 枣子树(江宁店)
# [详情] 417/3000 鹿园
# [详情] 418/3000 都会尚膳 上海宝华万豪酒店
# [详情] 419/3000 欧膳(新乐路店)
# [详情] 420/3000 HOME'S私房菜
# [详情] 421/3000 老正兴菜馆(福州路店)
# [详情] 422/3000 日珍日本餐厅
# [详情] 423/3000 外婆家(五角场店)
# [详情] 424/3000 东京屋(武定路店)
# [详情] 425/3000 粤1525
# [详情] 426/3000 小绍兴(云南店)
# [详情] 427/3000 THE CUT 牛排薯条色拉
# [详情] 428/3000 尚席 - 上海浦东丽晶酒店
# [详情] 429/3000 Eli Falafel (九江路店)
# [详情] 430/3000 Cafe Gray Deluxe
# [详情] 431/3000 Kebabs On The Grille(人民广场店)
# [详情] 432/3000 功德林(鸿翔大厦店)
# [详情] 433/3000 Calix
# [详情] 434/3000 The Plump Oyster
# [详情] 435/3000 Eileen
# [详情] 436/3000 Maan coffee
# [详情] 437/3000 蓝果丽印度餐厅
# [详情] 438/3000 醉东(静安嘉里店)
# [详情] 439/3000 兄弟烤肉
# [详情] 440/3000 Isola bar & grill
# [详情] 441/3000 意难忘
# [详情] 442/3000 mr willis
# [详情] 443/3000 Stone Brewing Tap Room
# [详情] 444/3000 Zeitgeistbites
# [详情] 445/3000 俏江南
# [详情] 446/3000 星巴克(豫园店)
# [详情] 447/3000 Wolfgang Puck 迪士尼小镇店
# [详情] 448/3000 麻布屋(浦东嘉里城店)
# [详情] 449/3000 上海比萨马上诺(上海商城店)
# [详情] 450/3000 张生记(正大广场店)
# [详情] 451/3000 莫尔顿海鲜牛排坊
# [详情] 452/3000 东方既白(浦东机场店)
# [详情] 453/3000 Yasmine's  Steakhouse
# [详情] 454/3000 上海俏江南(正大店)
# [详情] 455/3000 俏江南881会所
# [详情] 456/3000 苏浙汇(香港广场店)
# [详情] 457/3000 西悦·驿站 C Market 自助餐厅
# [详情] 458/3000 沃歌斯(胶州路店)
# [详情] 459/3000 藜麦西餐厅酒吧
# [详情] 460/3000 永兴餐厅
# [详情] 461/3000 万岛日本料理铁板烧(吴中店)
# [详情] 462/3000 上海藏珑泰极(田子坊店)
# [详情] 463/3000 保罗酒楼
# [详情] 464/3000 国际饭店西饼屋黄河路店
# [详情] 465/3000 马上诺(新天地店)
# [详情] 466/3000 布朗石酒吧
# [详情] 467/3000 壹阶层 (上海锦江汤臣洲际大酒店 )
# [详情] 468/3000 Oceans
# [详情] 469/3000 BIANCHI(浦东嘉里城店)
# [详情] 470/3000 NARISAWA Shanghai
# [详情] 471/3000 慧公馆(巨鹿路店)
# [详情] 472/3000 大堂酒廊
# [详情] 473/3000 Butler & White's With Guiness
# [详情] 474/3000 TOPS
# [详情] 475/3000 李教授
# [详情] 476/3000 酒池星座(新乐路店)
# [详情] 477/3000 Pistolera Mexican Cantina
# [详情] 478/3000 割烹遊
# [详情] 479/3000 Cantina Agave
# [详情] 480/3000 穹六人间
# [详情] 481/3000 点都德(龙之梦店)
# [详情] 482/3000 蟹黄鱼
# [详情] 483/3000 Smoki Moto雾山(上海漕河泾万丽酒店)
# [详情] 484/3000 屋有鲜
# [详情] 485/3000 小杨生煎(东方明珠店)
# [详情] 486/3000 Suntory Japanese Cuisine & Whisky
# [详情] 487/3000 大壶春(云南南路店)
# [详情] 488/3000 Roof P.m. Modern Dining
# [详情] 489/3000 洋房火锅(新天地店)
# [详情] 490/3000 Anokhi Bar & Grill
# [详情] 491/3000 新天世纪中餐厅（上海凯宾斯基大酒店）
# [详情] 492/3000 Yang's Dumpling
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d27119630-Reviews-Yang_s_Dumpling-Shanghai.html
# [详情] 493/3000 Bourbon Cookhouse
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d13985087-Reviews-Bourbon_Cookhouse-Shanghai.html
# [详情] 494/3000 满宝楼  (上海雅居乐万豪酒店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d4795971-Reviews-Man_Bao_Lou_Chinese_Restaurant-Shanghai.html
# [详情] 495/3000 La Cabane
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d7906266-Reviews-La_Cabane-Shanghai.html
# [详情] 496/3000 星巴克上海滨江店
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d2491428-Reviews-Starbucks_ShangHai_BinJiang-Shanghai.html
# [详情] 497/3000 老吉士酒楼(久光店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d10585869-Reviews-Lao_Ji_Shi_Restaurant_JiuGuang-Shanghai.html
# [详情] 498/3000 El Santo Tacos&Tequila
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d12478376-Reviews-El_Santo_Tacos_Tequila-Shanghai.html
# [详情] 499/3000 萨莉亚(南京东路店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d3391154-Reviews-Saizeriya_NanJing_East_Road-Shanghai.html
# [详情] 500/3000 Baker & Spice Café(IFC商场店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d4807348-Reviews-Baker_Spice_Cafe_IFC_ShangChang-Shanghai.html
# [详情] 501/3000 element fresh
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d4962845-Reviews-Element_fresh-Shanghai.html
# [详情] 502/3000 孔雀川菜(新天地店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d12230781-Reviews-Maurya_Sichuan_Cuisine_Xintiandi-Shanghai.html
# [详情] 503/3000 寿司屋(静安店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d2367314-Reviews-SushiO_Jing_an-Shanghai.html
# [详情] 504/3000 南伶酒家
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d3450005-Reviews-Nan_Ling_Restaurant-Shanghai.html
# [详情] 505/3000 翡翠酒家(新天地南里店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d10336788-Reviews-Crystal_Jade_Restaurant_Xintiandi_South_Li-Shanghai.html
# [详情] 506/3000 鼎泰丰(环贸广场店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d12550414-Reviews-Din_Tai_Fung_IAPM-Shanghai.html
# [详情] 507/3000 南蛮子云南烧烤吧
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d948160-Reviews-Southern_Barbarian-Shanghai.html
# [详情] 508/3000 孔雀厅
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d13608107-Reviews-The_Peacock_Room-Shanghai.html
# [详情] 509/3000 Godiva(新天地店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d5400392-Reviews-Godiva_Xintiandi-Shanghai.html
# [详情] 510/3000 山茶花铁板烧
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d3465721-Reviews-SAZANKA_Teppanyaki-Shanghai.html
# [详情] 511/3000 圆苑酒家(静安寺店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d4771967-Reviews-Yuan_Yuan_Restaurant_JingAnSi-Shanghai.html
# [详情] 512/3000 De Medici
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d14096811-Reviews-De_Medici-Shanghai.html
# [详情] 513/3000 Pierogi Ladies Polish Food
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d18966275-Reviews-Pierogi_Ladies_Polish_Food-Shanghai.html
# [详情] 514/3000 意膳坊
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d8706093-Reviews-Thought_For_Food-Shanghai.html
# [详情] 515/3000 逸谷(浦东嘉里城店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d3465065-Reviews-Yi_Gu_PuDong_Kerry_Cheng-Shanghai.html
# [详情] 516/3000 上海红塔豪华精选酒店-丹尼艾丽意大利餐厅
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d3512269-Reviews-Danieli_s_Italian_Restaurant-Shanghai.html
# [详情] 517/3000 Tipsy Fiddler
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d7362006-Reviews-Tipsy_Fiddler-Shanghai.html
# [详情] 518/3000 La Petanque
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d5572621-Reviews-La_Petanque-Shanghai.html
# [详情] 519/3000 莆田餐厅(南丰城店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d8736591-Reviews-Putien_Restaurant_Nanfeng_Cheng-Shanghai.html
# [详情] 520/3000 Gather Pizza
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d8774782-Reviews-Gather_Pizza-Shanghai.html
# [详情] 521/3000 ORENO
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d8616576-Reviews-ORENO-Shanghai.html
# [详情] 522/3000 圆苑酒家(愚园路店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d4805759-Reviews-Yuan_Yuan_Restaurant_YuYuan_Road-Shanghai.html
# [详情] 523/3000 小南国(新天地店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d3391234-Reviews-Shanghai_Min_Xintiandi-Shanghai.html
# [详情] 524/3000 卡萨诺瓦
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d870667-Reviews-Casanova_Italian_Restaurant-Shanghai.html
# [详情] 525/3000 C's PUB
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d3450193-Reviews-C_s_PUB-Shanghai.html
# [详情] 526/3000 Namaste India Restaurant - Authentic North & South Indian
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d11909713-Reviews-Namaste_Bistro-Shanghai.html
# [详情] 527/3000 星巴克(新天地店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d4803629-Reviews-Starbucks_Xintiandi-Shanghai.html
# [详情] 528/3000 Kinnjyou Inaka (J Hotel Shanghai Tower)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d26832048-Reviews-Kinnjyou_Inaka_J_Hotel_Shanghai_Tower-Shanghai.html
# [详情] 529/3000 Boxing Cat Brewery(思南路店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d4704411-Reviews-Boxing_Cat_Brewery_sinan_Mansions-Shanghai.html
# [详情] 530/3000 Papas Bierstube
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d3173371-Reviews-Papas_Bierstube-Shanghai.html
# [详情] 531/3000 Pera Turkish Restaurant & Bar
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d12167749-Reviews-Pera_Indian_and_Turkish_Restaurant_Bar-Shanghai.html
# [详情] 532/3000 Viva!
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d10775098-Reviews-Viva-Shanghai.html
# [详情] 533/3000 老盛昌苏州汤包馆(南京路店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d4704368-Reviews-Lao_Sheng_Chang_Su_Zhou_Tangbao_Guan-Shanghai.html
# [详情] 534/3000 新城饭店中餐厅
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d3391029-Reviews-Xincheng_Hotel_Chinese_Restaurant-Shanghai.html
# [详情] 535/3000 滨江大堂吧
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d15258928-Reviews-Riviera_Lounge-Shanghai.html
# [详情] 536/3000 鑫旺餐厅
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d3539941-Reviews-Xin_Wang_Restaurant-Shanghai.html
# [详情] 537/3000 JSTONE.意大利餐厅 （世茂52+店）
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d4761300-Reviews-Jstone_Italian_Kitchen_Bar_Shimao_52-Shanghai.html
# [详情] 538/3000 吉野家(先施店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d3450111-Reviews-Yoshinoya_XianShi-Shanghai.html
# [详情] 539/3000 Red Salt Indian Pakistani Restaurant
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d32682434-Reviews-Red_Salt_Indian_Pakistani_Restaurant-Shanghai.html
# [详情] 540/3000 申粤轩
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d1052930-Reviews-Shen_Yue_Xuan-Shanghai.html
# [详情] 541/3000 Cova(新天地北里店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d2386449-Reviews-COVA_Xintiandi_Store-Shanghai.html
# [详情] 542/3000 新意尚
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d8422354-Reviews-Vapiano-Shanghai.html
# [详情] 543/3000 粤珍轩 (金茂君悦大酒店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d4771371-Reviews-Canton_Grand_Hyatt_Shanghai-Shanghai.html
# [详情] 544/3000 枣子树(江宁店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d10430635-Reviews-Vegetarian_Life_Style-Shanghai.html
# [详情] 545/3000 必胜客(浦东机场店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d4806880-Reviews-Pizza_Hut_PuDong_Airport-Shanghai.html
# [详情] 546/3000 % Arabica
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d14041831-Reviews-Arabica-Shanghai.html
# [详情] 547/3000 夏朵花园
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d3391702-Reviews-Xia_Duo_HuaYuan-Shanghai.html
# [详情] 548/3000 豆捞坊(百乐门店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d1218617-Reviews-Dou_Lao_Fang_BaiLeMen-Shanghai.html
# [详情] 549/3000 Chateau Chili
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d28416239-Reviews-Chateau_Chili-Shanghai.html
# [详情] 550/3000 Si Ji Xuan(Four Seasons Hotel Shanghai)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d7937022-Reviews-Si_Ji_Xuan_Four_Seasons_Hotel_Shanghai-Shanghai.html
# [详情] 551/3000 The Lakeside Veggie
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d25941168-Reviews-The_Lakeside_Veggie-Shanghai.html
# [详情] 552/3000 王鼎日本料理铁板烧(世茂商都店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d3449185-Reviews-WangDing_Japanese_Restaurant_Yakiniku_ShiMao_ShangDou-Shanghai.html
# [详情] 553/3000 藏酒轩
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d1082143-Reviews-NAPA_Wine_Bar_and_Kitchen-Shanghai.html
# [详情] 554/3000 摩卡站
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d12946630-Reviews-Moka_Bros-Shanghai.html
# [详情] 555/3000 J Prime牛排海鲜餐厅
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d15812136-Reviews-J_Prime-Shanghai.html
# [详情] 556/3000 平成屋日式料理店(广西北路店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d3448893-Reviews-Pingcheng_House_Japanese_Restaurant_Guangxi_North_Road-Shanghai.html
# [详情] 557/3000 Momenti
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d15585146-Reviews-Momenti-Shanghai.html
# [详情] 558/3000 德兴馆(山西南路店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d3391091-Reviews-DeXing_Guan_ShanXi_South_Road-Shanghai.html
# [详情] 559/3000 Bi feng tang
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d3354026-Reviews-Bi_feng_tang-Shanghai.html
# [详情] 560/3000 上海鸭王(上海淮海店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d1751659-Reviews-ShangHai_Ya_Wang_ShangHai_HuaiHai-Shanghai.html
# [详情] 561/3000 Kebabs On The Grille Laowaijie Branch
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d17531654-Reviews-Kebabs_On_The_Grille_Laowaijie_Branch-Shanghai.html
# [详情] 562/3000 Punch Room
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d20671428-Reviews-Punch_Room-Shanghai.html
# [详情] 563/3000 匠造烘焙
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d15300518-Reviews-Artisan_Bakery-Shanghai.html
# [详情] 564/3000 La Terrazza 高空露台酒吧
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d27544594-Reviews-La_Terrazza_Bar-Shanghai.html
# [详情] 565/3000 Jen Dow Vegetarian
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d3734288-Reviews-Jen_Dow_Vegetarian-Shanghai.html
# [详情] 566/3000 上海新疆风味饭馆维吾尔餐厅
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d1219829-Reviews-Shanghai_Xinjiang_Uygur_Restaurant-Shanghai.html
# [详情] 567/3000 东来顺(外滩店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d10775457-Reviews-Dong_Lai_Shun_WaiTan-Shanghai.html
# [详情] 568/3000 罗斯福牛扒馆 Steak By Roosevelt
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d27729882-Reviews-Steak_By_Roosevelt-Shanghai.html
# [详情] 569/3000 Big Bamboo (虹桥店)
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d5457489-Reviews-Big_Bamboo_Hongqiao-Shanghai.html
# [详情] 570/3000 TRES PERROS
#   详情页失败：403 Client Error: Forbidden for url: https://cn.tripadvisor.com/Restaurant_Review-g308272-d10753896-Reviews-TRES_PERROS-Shanghai.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 102
#     100     print("已保存到 tripadvisor_shanghai.csv，共抓取条数：", len(result))
#     101     return result
# --> 102 df = main()
#     103 df.head(10)
#
# Cell In[2], line 95, in main()
#      93     info.update({"名称": row['名称'], "链接": row['链接']})
#      94     records.append(info)
# ---> 95     time.sleep(2 + random.random()*2)
#      97 # 3) 合并并保存为 CSV
#      98 result = pd.DataFrame(records, columns=['名称','链接','评分','评价数','类别','人均','地址'])
#
# KeyboardInterrupt:

# %% [markdown]
# <p style="text-indent:2em;">
# <strong>第二阶段：</strong> 经过一次失败后，与该网页逐渐"熟悉"。但是我们天真认为该网页是按照访问次数来封的，觉得之前试爬取的时候浪费了很多访问机会。于是第二天没有做很多修改直接开始爬，结果不出意料IP马上被封了，后面总结出是更具访问频率和其他方面来封的。由于<span style="color: red;">时间紧迫</span>，只好请代理IP来帮助（小氪一点），并且经过讨论，我们不再天真，加上了边跑边存的机制，并且清楚还会出现访问失败的情况，于是用另外一个visited_links.txt文件来存取访问过的餐厅的网址，方便后续对失败的网页再次访问。由于本次采用的是串行爬取，并且为了模拟真人，每次爬取休息时间也较长，所以<strong><span style="color: blue;">爬了6个小时以上</span></strong>。但是，<span style="color: red;">即使这样😢</span>，我们仍只爬到了1939条数据（保存在tripadvisor_shanghai.csv中），根据输出显示与AI咨询，总结原因如下：
#
# 1.由于财力有限，没有用很好的IP，导致越爬到后面，有限的代理IP越容易被封禁，这也符合输出显示中的现象。
#
# 2.网页通过JavaScript部分采用了动态渲染和更新，而requests + lxml只能能拿到初始化好的静态的HTML中的内容，导致很多空的爬取。借助AI，也尝试了利用Selenium来模拟真实的浏览器访问，最终以访问速度慢以及效果不佳而放弃。
#
# 3.列表页爬取失败直接缺失30条，总共有30条列表页访问失败；其次访问详情页的时候也会失败，最终只获得1939条数据，并且这些数据有些残缺。
# 此处**失败**包括访问页面时的403问题（IP被封）和超出了提前设定好的HTML获取时间15s。
# </p>
# <p style="text-indent:2em;">代码如下：</p>

# %%
import requests  # 用于发送 HTTP 请求
from lxml import etree  # 用于解析 HTML
import pandas as pd  # 用于数据处理与保存
import time  # 用于控制爬取时间间隔
import random  # 用于生成随机延时，防止被封禁
import re  # 用于正则表达式匹配
import os  # 用于文件操作

BASE_URL = "https://cn.tripadvisor.com"  # TripAdvisor 中国站基础 URL

# 快代理配置
tunnel = "t828.kdltpspro.com:15818"  # 代理地址:端口
username = "t14703884308185"  # 代理用户名
password = "a1o7xj86"  # 代理密码
proxies = {
    "http": f"http://{username}:{password}@{tunnel}",  # HTTP 代理
    "https": f"http://{username}:{password}@{tunnel}"  # HTTPS 代理
}

# HTTP 请求头，模拟浏览器行为
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
                  '(KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'Accept-Language': 'zh-CN,zh;q=0.9',
    'Referer': 'https://cn.tripadvisor.com/',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'Accept-Encoding': 'gzip, deflate, br',
}

def safe_print(text):
    """安全打印，捕获 Unicode 编码错误"""
    try:
        print(text)
    except UnicodeEncodeError:
        # 遇到无法编码字符时忽略后打印
        print(text.encode('utf-8', errors='ignore').decode('utf-8'))


def load_visited_links(file="visited_links.txt"):
    """加载已访问链接，防止重复爬取"""
    if os.path.exists(file):
        with open(file, "r", encoding="utf-8") as f:
            return set(f.read().splitlines())  # 返回存储的链接集合
    return set()  # 若文件不存在返回空集合


def save_visited_links(visited_links, file="visited_links.txt"):
    """将新访问的链接追加写入文件"""
    with open(file, "a", encoding="utf-8") as f:
        for link in visited_links:
            f.write(f"{link}\n")  # 每行写入一个链接


def fetch_list_pages(pages=1):
    """抓取列表页，提取餐厅名称和链接"""
    restaurants = []
    for page in range(pages):
        offset = page * 30  # 每页 30 条记录
        url = f"{BASE_URL}/FindRestaurants?geo=308272&offset={offset}&sort=FEATURED&broadened=false"
        safe_print(f"[列表] 爬第 {page+1} 页：{url}")
        try:
            # 请求列表页
            r = requests.get(url, headers=headers, proxies=proxies, timeout=15)
            r.raise_for_status()
        except Exception as e:
            safe_print(f"  列表页失败：{e}")
            continue

        tree = etree.HTML(r.text)  # 解析 HTML
        # 定位包含餐厅信息的 div
        divs = tree.xpath("//div[contains(@class,'mtnKn') and contains(@class,'ngXxk')]")
        for d in divs:
            raw = d.xpath("string(.)").strip()  # 获取文本并去除空白
            name = re.sub(r'^\d+\.\s*', '', raw)  # 去掉序号前缀
            href = d.xpath("ancestor::a[1]/@href")  # 向上查找链接
            if href:
                restaurants.append({"名称": name, "链接": BASE_URL + href[0]})
        time.sleep(4 + random.random() * 2)  # 随机延时 2-4 秒
    return restaurants


def fetch_detail(html_text):
    """解析详情页，提取评分、评价数、类别、人均、地址"""
    tree = etree.HTML(html_text)
    detail = {}
    # 提取评分
    rating = tree.xpath("//div[@data-automation='bubbleRatingValue']/text()")
    detail['评分'] = rating[0].strip() if rating else None

    # 提取评价数
    reviews = tree.xpath("//div[@data-automation='bubbleReviewCount']//text()")
    if reviews:
        m = re.search(r'([\d,]+)', "".join(reviews))
        detail['评价数'] = m.group(1).replace(',', '') if m else None
    else:
        detail['评价数'] = None

    # 提取类别和人均
    items = tree.xpath("//span[contains(@class,'HUMGB') and contains(@class,'cPbcf')]//a/span/text()")
    if items:
        last = items[-1].strip()
        if '¥' in last:
            detail['人均'] = last
            detail['类别'] = ",".join(i.strip() for i in items[:-1] if i.strip())
        else:
            detail['人均'] = None
            detail['类别'] = ",".join(i.strip() for i in items if i.strip())
    else:
        detail['人均'] = None
        detail['类别'] = None

    # 提取地址
    addr = tree.xpath("//span[@data-automation='restaurantsMapLinkOnName']/text()")
    if not addr:
        addr = tree.xpath("//button[@data-automation='restaurantsMapLinkOnName']//span/text()")
    detail['地址'] = addr[0].strip() if addr else None
    return detail


def main(pages=100):
    output_file = "tripadvisor_shanghai.csv"  # 输出 CSV 文件名
    visited_links = load_visited_links()  # 加载已访问链接
    all_data = []  # 存储本次爬取的数据

    # 如果输出文件不存在，则写入表头
    if not os.path.exists(output_file):
        pd.DataFrame(columns=['名称', '链接', '评分', '评价数', '类别', '人均', '地址'])\
          .to_csv(output_file, index=False, encoding="utf-8-sig")

    # 抓取列表页数据
    lst = fetch_list_pages(pages)

    new_visited_links = set()  # 本次新增访问链接
    # 逐条抓取详情页并写入 CSV
    for idx, row in enumerate(lst):
        if row['链接'] in visited_links:
            safe_print(f"  跳过已访问: {row['链接']}")
            continue
        safe_print(f"[详情] {idx+1}/{len(lst)} {row['名称']}")
        try:
            r = requests.get(row['链接'], headers=headers, proxies=proxies, timeout=15)
            r.raise_for_status()
            info = fetch_detail(r.text)
        except Exception as e:
            safe_print(f"  详情页失败：{e}")
            info = {'评分': None, '评价数': None, '类别': None, '人均': None, '地址': None}
        info.update({"名称": row['名称'], "链接": row['链接']})
        # 追加写入 CSV
        pd.DataFrame([info]).to_csv(output_file, mode="a", header=False, index=False, encoding="utf-8-sig")
        new_visited_links.add(row['链接'])  # 记录新访问链接
        all_data.append(info)  # 收集数据
        time.sleep(5 + random.random() * 3)  # 随机延时

    # 保存本次访问链接
    save_visited_links(new_visited_links)
    safe_print(f"完成，结果保存在 {output_file}")
    return pd.DataFrame(all_data)

# 调用入口
df = main(100)  # 默认抓取 100 页

# %% [markdown]
# <p style="text-indent:2em;">
# <strong>第三阶段：</strong><span style="color: blue;">最后的倔强</span>阶段。本着不放弃最初设定的3000数据的梦想😥，首先检查了阶段二爬下来的1939条数据与相应的网页原代码，发现有的数据为空是因为<strong>有的网页本身HTML不同，有的网页本来就不包括人均、类别等数据</strong>，于是我们对xpath路径做了兼容补充。然后又尝试了多种方法，比如，根据第二阶段保存的餐厅链接去访问访问失败了的网页的数据，但最终都以各种原因失败而告终，并且还爱在不断的尝试中<span style="color: red;">不小心弄丢了</span>阶段二保存了的visited_links.txt文件，这也成为压死骆驼的最后一根稻草😫，导致无法再直接重新爬取失败了的网页数据了。然后又尝试了直接重新爬取，比较可行的是下面的方案：除了补充xpath路径外，还将原来的串行爬取改成了并行，极大程度上提升了爬行速度，但是被封的概率也极大提升了，不管采用几线并行，中间休息多少秒都无法再爬取更多有效信息了。
# </p>
#
# <p style="text-indent:2em;">另外，本次尝试还了解到一个<strong><span style="color: blue;">疑惑冷知识:</strong>  尝试了免费体验的代理IP，各方面性能比我们之前小氪的代理IP要好，并且查看了续费价格也更贵，但是实际效果为什么就是比我们之前的差（起初还以为如获至宝😢）</p>
# <p style="text-indent:2em;">代码如下：</p>

# %%
import requests  # 用于发送 HTTP 请求
from lxml import etree  # 用于解析 HTML
import pandas as pd  # 用于数据处理与保存
import time  # 用于控制爬取间隔
import random  # 用于生成随机延时
import re  # 用于正则匹配
import os  # 用于文件和目录操作
from requests.adapters import HTTPAdapter  # 用于设置重试策略
from urllib3.util.retry import Retry  # 重试策略配置
from concurrent.futures import ThreadPoolExecutor, as_completed  # 并发抓取

# ----- 基础常量配置 -----
BASE_URL = "https://cn.tripadvisor.com"  # TripAdvisor 中国站基础 URL
TUNNEL = "s659.kdltps.com:15818"  # 代理服务器地址:端口
USERNAME = "t14704858604183"  # 代理用户名
PASSWORD = "jz5qpwel"  # 代理密码
# 构造代理字典，requests 会自动识别
PROXIES = {
    "http": f"http://{USERNAME}:{PASSWORD}@{TUNNEL}",
    "https": f"http://{USERNAME}:{PASSWORD}@{TUNNEL}"
}
# HTTP 请求头，伪装浏览器
HEADERS = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 '
                  '(KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Language': 'zh-CN,zh;q=0.9',
    'Referer': BASE_URL,
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'Accept-Encoding': 'gzip, deflate, br',
}

# ----- 输出与进度文件 -----
OUTPUT_FILE = "tripadvisor_shanghai.csv"  # 最终结果 CSV
FAILURES_DIR = "failures"  # 存放失败详情的文件夹
FAILURES_FILE = os.path.join(FAILURES_DIR, "failed_details.csv")  # 失败详情 CSV
PROGRESS_FILE = "fetched_pages.txt"  # 存放已抓取列表页页码
COLUMNS = ['名称', '链接', '评分', '评价数', '类别', '人均', '地址']  # CSV 列顺序
TOTAL_PAGES = 100  # 列表页总数
MAX_DETAILS_PER_RUN = 90  # 本次运行最多抓取详情数

# ----- 初始化文件与目录 -----
os.makedirs(FAILURES_DIR, exist_ok=True)  # 确保失败目录存在
# 若输出文件不存在，则写入表头
if not os.path.exists(OUTPUT_FILE):
    pd.DataFrame(columns=COLUMNS).to_csv(OUTPUT_FILE, index=False, encoding='utf-8-sig')
# 若失败文件不存在，则写入表头
if not os.path.exists(FAILURES_FILE):
    pd.DataFrame(columns=['名称','链接','错误信息']).to_csv(FAILURES_FILE, index=False, encoding='utf-8-sig')

# ----- Session 初始化（带重试与代理） -----
session = requests.Session()
# 配置重试策略：最多重试 5 次，针对特定状态码
retry = Retry(
    total=5,
    backoff_factor=0.3,
    status_forcelist=[403, 500, 502, 503, 504],
    allowed_methods=frozenset(["GET"])
)
# 将重试策略安装到 session
session.mount('http://', HTTPAdapter(max_retries=retry))
session.mount('https://', HTTPAdapter(max_retries=retry))
# 更新代理与请求头到 session
session.proxies.update(PROXIES)
session.headers.update(HEADERS)


def safe_sleep(min_sec=2, max_sec=4):
    """随机睡眠，避免过快请求触发反爬"""
    time.sleep(min_sec + random.random() * (max_sec - min_sec))


def fetch_list_pages(pages=TOTAL_PAGES, max_retries=3):
    """
    抓取列表页，提取餐厅名和详情链接，维护进度与去重
    :param pages: 总页数
    :param max_retries: 单页最大重试次数
    :return: 新的餐厅链接列表
    """
    restaurants = []  # 存储本次需抓取的餐厅
    fetched_pages = set()
    # 读取已抓取页码，避免重复
    if os.path.exists(PROGRESS_FILE):
        with open(PROGRESS_FILE, 'r') as f:
            fetched_pages = set(int(line.strip()) for line in f if line.strip().isdigit())
    # 读取已写入 OUTPUT_FILE 的链接，避免重复抓取详情
    if os.path.exists(OUTPUT_FILE):
        fetched_df = pd.read_csv(OUTPUT_FILE, usecols=["链接"], encoding='utf-8-sig')
        fetched_urls = set(fetched_df['链接'].dropna().unique())
    else:
        fetched_urls = set()

    # 遍历每个列表页
    for page in range(pages):
        if page in fetched_pages:
            print(f"[跳过] 第 {page+1} 页已爬取")
            continue

        offset = page * 30
        url = (f"{BASE_URL}/FindRestaurants?geo=308272"
               f"&offset={offset}&sort=FEATURED&broadened=false")
        print(f"[列表] 第 {page+1}/{pages} 页：{url}")

        # 重试机制
        for attempt in range(1, max_retries+1):
            try:
                r = session.get(url, timeout=15)  # 发请求
                r.raise_for_status()
                tree = etree.HTML(r.text)
                # 定位包含餐厅信息的节点
                divs = tree.xpath("//div[contains(@class,'mtnKn') and contains(@class,'ngXxk')]")
                for d in divs:
                    raw = d.xpath("string(.)").strip()
                    name = re.sub(r'^\d+\.\s*', '', raw)  # 去序号
                    href = d.xpath("ancestor::a[1]/@href")
                    if href:
                        full_url = BASE_URL + href[0]
                        # 若未在已抓取列表中，则添加
                        if full_url not in fetched_urls:
                            restaurants.append({"名称": name, "链接": full_url})
                            # 达到上限则提前返回
                            if len(restaurants) >= MAX_DETAILS_PER_RUN:
                                print(f"✅ 达到上限 {MAX_DETAILS_PER_RUN} 条，提前停止")
                                with open(PROGRESS_FILE, 'a') as f:
                                    f.write(f"{page}\n")
                                return restaurants
                # 当前页成功抓取后，记录页码
                with open(PROGRESS_FILE, 'a') as f:
                    f.write(f"{page}\n")
                break

            except Exception as e:
                print(f"  [列表页重试 {attempt}/{max_retries}] 失败: {e}")
                safe_sleep(3,5)
        else:
            print(f"  ❌ 列表页最终失败，跳过：{url}")

        safe_sleep(2,4)

    return restaurants


def fetch_detail(row, max_retries=3):
    """
    抓取单个餐厅的详情页并解析，失败记录到文件
    :param row: 包含 '链接' 和 '名称' 的 dict
    :param max_retries: 最大重试次数
    :return: 含详情字段的 dict
    """
    url, name = row['链接'], row['名称']
    detail = {}
    for attempt in range(1, max_retries+1):
        try:
            print(f"[详情] {name} - 尝试 {attempt}/{max_retries}")
            r = session.get(url, timeout=15)
            r.raise_for_status()
            tree = etree.HTML(r.text)
            # 提取评分
            rt = tree.xpath("//div[@data-automation='bubbleRatingValue']/text()")
            detail['评分'] = rt[0].strip() if rt else '未标注'
            # 提取评价数
            rev = tree.xpath("//div[@data-automation='bubbleReviewCount']//text()")
            detail['评价数'] = (
                re.search(r'([\d,]+)', "".join(rev)).group(1).replace(',','')
                if rev and re.search(r'([\d,]+)', "".join(rev)) else '未标注'
            )
            # 提取类别和人均
            items = tree.xpath(
                "//span[contains(@class,'HUMGB') and contains(@class,'cPbcf')]//a/span/text()"
            )
            if items:
                last = items[-1].strip()
                if '¥' in last:
                    detail['人均'] = last
                    detail['类别'] = ",".join(i.strip() for i in items[:-1] if i.strip()) or '未标注'
                else:
                    detail['人均'] = '未标注'
                    detail['类别'] = ",".join(i.strip() for i in items if i.strip()) or '未标注'
            else:
                detail['类别'] = detail['人均'] = '未标注'
            # 提取地址
            addr = tree.xpath("//span[@data-automation='restaurantsMapLinkOnName']/text()")
            if not addr:
                addr = tree.xpath("//button[@data-automation='restaurantsMapLinkOnName']//span/text()")
            detail['地址'] = addr[0].strip() if addr else '未标注'
            break

        except requests.exceptions.HTTPError as e:
            code = e.response.status_code
            if code == 403 and attempt < max_retries:
                print(f"  [403重试 {attempt}/{max_retries}]")
                safe_sleep(3,5)
                continue
            err = f"HTTP{code}"
        except Exception as e:
            err = str(e)
        # 失败时记录到失败文件
        detail = dict.fromkeys(['评分','评价数','类别','人均','地址'], '未标注')
        with open(FAILURES_FILE, 'a', encoding='utf-8-sig', newline='') as f:
            pd.DataFrame([{'名称':name,'链接':url,'错误信息':err}]).to_csv(
                f, header=False, index=False, encoding='utf-8-sig'
            )
        print(f"  ❌ 最终失败：{name} - {err}")
        break

    safe_sleep(2,4)
    return {**row, **detail}  # 合并基本信息和详情


def main():
    # 读取已抓取过的链接，用于去重详情爬取
    if os.path.exists(OUTPUT_FILE):
        fetched_df = pd.read_csv(OUTPUT_FILE, encoding='utf-8-sig', usecols=['链接'])
        fetched_urls = set(fetched_df['链接'].dropna().unique())
    else:
        fetched_urls = set()

    # 获取列表页链接
    lst = fetch_list_pages()
    # 过滤掉已抓过的链接
    lst = [r for r in lst if r['链接'] not in fetched_urls]
    print(f"实际需要爬取详情页：{len(lst)} 条")

    if not lst:
        print("🎉 没有新链接需要抓取，本轮结束")
        return

    # 并发抓取详情页，最多 5 个线程
    completed = 0
    with ThreadPoolExecutor(max_workers=5) as executor:
        futures = {executor.submit(fetch_detail, r): r for r in lst}
        for future in as_completed(futures):
            info = future.result()
            completed += 1
            print(f"[进度] {completed}/{len(lst)}")
            # 将每条结果追加写入 OUTPUT_FILE
            pd.DataFrame([info])[COLUMNS].to_csv(
                OUTPUT_FILE, mode='a', header=False, index=False, encoding='utf-8-sig'
            )
            # 每 30 条结果暂停 60 秒
            if completed % 30 == 0:
                print("  —— 长休 60 秒 ——")
                time.sleep(60)

    # 去重，确保链接唯一
    df = pd.read_csv(OUTPUT_FILE, encoding='utf-8-sig', dtype=str)
    df.drop_duplicates(subset=['链接'], keep='first', inplace=True)
    df.to_csv(OUTPUT_FILE, index=False, encoding='utf-8-sig')
    print(f"✅ 本轮完成：新增 {completed} 条，累计 {len(df)} 条；失败见 {FAILURES_FILE}")

if __name__ == "__main__":
    main()
# Out:
# [列表] 第 1/100 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=0&sort=FEATURED&broadened=false
# [列表] 第 2/100 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=30&sort=FEATURED&broadened=false
# [列表] 第 3/100 页：https://cn.tripadvisor.com/FindRestaurants?geo=308272&offset=60&sort=FEATURED&broadened=false
# ✅ 达到上限 90 条，提前停止
# 实际需要爬取详情页：90 条
# [详情] 上海佳家汤包(黄河路店) - 尝试 1/3
# [详情] 星巴克臻选上海烘焙工坊 - 尝试 1/3
# [详情] 小杨生煎馆(吴江路店) - 尝试 1/3
# [详情] ROOF (The Shanghai EDITION) - 尝试 1/3
# [详情] 金轩(上海浦东丽思卡尔顿酒店) - 尝试 1/3
# [详情] 上海小杨生煎(黄河路店) - 尝试 1/3
# [进度] 1/90
# [详情] 小杨生煎(宁波路店) - 尝试 1/3
# [进度] 2/90
# [详情] Flair Rooftop - 尝试 1/3[进度] 3/90
#
# [详情] 莉莲蛋挞(四季坊店) - 尝试 1/3
# [进度] 4/90
# [详情] Scena di Angelo 意大利餐厅 - 尝试 1/3[进度] 5/90
#
# [详情] Yone餐厅酒吧 (上海艾迪逊酒店) - 尝试 1/3[进度] 6/90
#
# [详情] 怡咖啡 - 尝试 1/3
# [进度] 7/90
# [详情] 上海香溢培客(安福路店) - 尝试 1/3
# [进度] 8/90
# [详情] Hakkasan - 尝试 1/3
# [进度] 9/90
# [详情] 芝乐坊餐厅 - 尝试 1/3
# [进度] 10/90
# [详情] Aura酒廊及爵士酒吧(上海浦东丽思卡尔顿酒店) - 尝试 1/3[进度] 11/90
#
# [详情] The Fellas - 尝试 1/3[进度] 12/90
#
# [详情] 花马天堂云南餐厅(外滩店) - 尝试 1/3[进度] 13/90
#
# [详情] Goodfellas意大利餐厅 - 尝试 1/3
# [进度] 14/90
# [详情] 上海姥姥 - 尝试 1/3
# [进度] 15/90
# [详情] 上海夜上海(新天地太平湖店) - 尝试 1/3
# [进度] 16/90
# [详情] BREAD etc. - 尝试 1/3[进度] 17/90
#
# [详情] The MEAT∙扒-浦东嘉里大酒店 - 尝试 1/3[进度] 18/90
#
# [详情] Shanghai Tavern (The Shanghai EDITION) - 尝试 1/3[进度] 19/90
#
# [详情] Mr & Mrs Bund - French Seafood-Steak House by Paul Pairet - 尝试 1/3
# [进度] 20/90
# [详情] 里维埃拉松鹤楼(外滩店) - 尝试 1/3
# [进度] 21/90
# [详情] 味香斋(雁荡路店) - 尝试 1/3[进度] 22/90
#
# [详情] 艾菲斯餐厅土耳其&地中海美食 - 尝试 1/3[进度] 23/90
#
# [详情] 塔金摩洛哥餐厅 - 尝试 1/3
# [进度] 24/90
# [详情] 两咖啡 - 尝试 1/3
# [进度] 25/90
# [详情] 夏宫 - 尝试 1/3
# [进度] 26/90
# [详情] 龙凤厅 - 尝试 1/3
# [进度] 27/90
# [详情] 久久滴水洞(茂名南路店) - 尝试 1/3[进度] 28/90
#
# [详情] 咖啡苑 - 尝试 1/3[进度] 29/90
#
# [详情] 成隆行蟹王府 - 尝试 1/3[进度] 30/90
#
#   —— 长休 60 秒 ——
# [详情] The Captain - 尝试 1/3
# [详情] 浦江汇 - 尝试 1/3
# [详情] Polux by Paul Pairet - 尝试 1/3
# [详情] 大董海参店(环贸iapm店) - 尝试 1/3
# [详情] The Nest - 尝试 1/3
# [详情] 鼎泰丰(上海新天地店) - 尝试 1/3
# [详情] 芭芭露莎 - 尝试 1/3
# [详情] POP露台餐厅与酒吧 - 尝试 1/3
# [详情] Mercato by Jean-Georges - 尝试 1/3
# [详情] 罗斯福公馆 - 尝试 1/3
# [详情] 耶里夏丽新疆餐厅(南京东路店) - 尝试 1/3
# [详情] 鼎泰丰(环球金融中心店) - 尝试 1/3
# [详情] 古铜法式餐厅 - 尝试 1/3
#   ❌ 最终失败：大董海参店(环贸iapm店) - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Read timed out.
# [详情] 御宝轩 - 尝试 1/3
# [详情] Palatino Roman Cuisine - 尝试 1/3
# [详情] Vedas 印度餐厅(常熟路店) - 尝试 1/3
# [详情] 新大陆中国厨房 - 尝试 1/3
# [详情] 尚牛社会（上海商城） - 尝试 1/3
# [详情] Zeitgeist - 尝试 1/3
# [详情] 莫尔顿牛排坊 - 尝试 1/3
# [详情] 老吉士酒家(天平路店) - 尝试 1/3
# [详情] Eli Falafel - 尝试 1/3
# [详情] 上海海底捞火锅店(张杨路店) - 尝试 1/3
# [详情] Long Bar 廊吧 （上海外滩华尔道夫酒店） - 尝试 1/3
# [详情] Ultraviolet by Paul Pairet - 尝试 1/3
# [详情] 帕夏土耳其餐厅 - 尝试 1/3
# [详情] 龙门阵茶屋川菜馆 - 尝试 1/3
# [详情] 8 1/2 Otto e Mezzo BOMBANA - 尝试 1/3
# [详情] 泰廊 - 尝试 1/3
#   ❌ 最终失败：Long Bar 廊吧 （上海外滩华尔道夫酒店） - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Read timed out.
# [详情] Bella Napoli(南汇路店) - 尝试 1/3
# [详情] 上海绿波廊(豫园路店) - 尝试 1/3
#   ❌ 最终失败：Palatino Roman Cuisine - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Read timed out.
# [详情] 蓝蛙(环球金融中心店) - 尝试 1/3
# [详情] 新荣记(上海广场店) - 尝试 1/3
# [详情] ElWilly - 尝试 1/3
# [进度] 31/90
# [进度] 32/90
# [进度] 33/90
# [进度] 34/90
# [进度] 35/90
# [进度] 36/90
# [进度] 37/90
# [进度] 38/90
# [进度] 39/90
# [进度] 40/90
# [进度] 41/90
# [进度] 42/90
# [进度] 43/90
# [进度] 44/90
# [进度] 45/90
# [进度] 46/90
# [进度] 47/90
# [进度] 48/90
# [进度] 49/90
# [进度] 50/90
# [进度] 51/90
# [进度] 52/90
# [进度] 53/90
# [进度] 54/90
# [进度] 55/90
# [进度] 56/90
# [进度] 57/90
# [进度] 58/90
# [进度] 59/90
# [进度] 60/90
#   —— 长休 60 秒 ——
#   ❌ 最终失败：蓝蛙(环球金融中心店) - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d802193-Reviews-Blue_Frog_SWFC-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
#   ❌ 最终失败：新荣记(上海广场店) - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d4802921-Reviews-Xin_Rong_Ji_Shanghai_Plaza-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
# [详情] The COOK•厨 - 尝试 1/3
# [详情] 1515牛排馆•酒吧 - 尝试 1/3
#   ❌ 最终失败：Bella Napoli(南汇路店) - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Read timed out.
#   ❌ 最终失败：ElWilly - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d1098017-Reviews-El_Willy-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
#   ❌ 最终失败：上海海底捞火锅店(张杨路店) - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Read timed out.
# [详情] La Parisienne - 尝试 1/3
# [详情] 耶里夏丽(东方店) - 尝试 1/3
# [详情] Da Ivo 意大利魔镜餐厅 - 尝试 1/3
#   ❌ 最终失败：The COOK•厨 - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d2257750-Reviews-The_COOK-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
# [详情] 沈大成(南京东路店) - 尝试 1/3
#   ❌ 最终失败：耶里夏丽(东方店) - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d4446834-Reviews-Yershari_Xinjiang_Restaurant_dongfang-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
#   ❌ 最终失败：1515牛排馆•酒吧 - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d4549873-Reviews-The_1515_West_Chophouse_Bar-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
#   ❌ 最终失败：Da Ivo 意大利魔镜餐厅 - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d7163028-Reviews-Da_Ivo-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
# [详情] 华懋阁 - 尝试 1/3
# [详情] Calypso地中海餐厅 - 尝试 1/3
# [详情] 旋景餐厅 - 尝试 1/3
#   ❌ 最终失败：沈大成(南京东路店) - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d3449957-Reviews-Shen_DaCheng_NanJing_East_Road-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
#   ❌ 最终失败：La Parisienne - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d9739828-Reviews-La_Parisienne-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
# [详情] 孔乙己酒家 - 尝试 1/3
#   ❌ 最终失败：华懋阁 - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d1925951-Reviews-The_Cathay_Room-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
#   ❌ 最终失败：旋景餐厅 - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d1552293-Reviews-Epicure_on_45-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
# [详情] 大蒜土耳其餐厅 - 尝试 1/3
# [详情] RAW Eatery And Wood Grill - 尝试 1/3
#   ❌ 最终失败：Calypso地中海餐厅 - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d6280797-Reviews-Calypso_Restaurant_Lounge-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
# [详情] 人和馆 - 尝试 1/3
# [详情] 东方明珠旋转餐厅 - 尝试 1/3
#   ❌ 最终失败：孔乙己酒家 - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d4605842-Reviews-KongYiJi_Restaurant-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
#   ❌ 最终失败：大蒜土耳其餐厅 - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d3872568-Reviews-Garlic-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
# [详情] 恰餐厅与酒吧 - 尝试 1/3
#   ❌ 最终失败：RAW Eatery And Wood Grill - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d10488757-Reviews-Raw_Eatery_And_Wood_Grill-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
#   ❌ 最终失败：人和馆 - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d10835963-Reviews-Ren_He_Guan-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
# [详情] Al Borgo - 尝试 1/3
# [进度] 61/90
# [进度] 62/90
# [进度] 63/90
# [进度] 64/90
# [进度] 65/90
# [进度] 66/90
# [进度] 67/90
# [进度] 68/90
# [进度] 69/90
# [进度] 70/90
# [进度] 71/90
# [进度] 72/90
# [进度] 73/90
# [进度] 74/90
# [进度] 75/90
# [进度] 76/90
# [进度] 77/90
# [进度] 78/90
# [进度] 79/90
# [进度] 80/90
# [详情] 上海香料艺术印度餐厅（大沽路店） - 尝试 1/3[进度] 81/90
#
# [详情] WET® 泳池酒吧 - 尝试 1/3
# [进度] 82/90
#   ❌ 最终失败：上海香料艺术印度餐厅（大沽路店） - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d2190323-Reviews-Masala_Art-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
#   ❌ 最终失败：Al Borgo - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d10431599-Reviews-Al_Borgo-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
#   ❌ 最终失败：WET® 泳池酒吧 - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d12864725-Reviews-WET_BAR_W_Shanghai_The_Bund-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
# [详情] 外婆家(南京西路店分店) - 尝试 1/3[进度] 83/90
#
# [详情] 丽笙星空酒吧 - 尝试 1/3
# [进度] 84/90
#   ❌ 最终失败：东方明珠旋转餐厅 - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d3449881-Reviews-Oriental_Pearl_Revolving_Restaurant-Shanghai.html (Caused by ReadTimeoutError("HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Read timed out. (read timeout=15)"))
# [详情] Speak Low - 尝试 1/3
# [进度] 85/90
# [进度] 86/90
#   ❌ 最终失败：Speak Low - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d7885820-Reviews-Speak_Low-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
#   ❌ 最终失败：恰餐厅与酒吧 - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d2177921-Reviews-CHAR_bar_and_grill-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
# [进度] 87/90
# [进度] 88/90
#   ❌ 最终失败：丽笙星空酒吧 - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d5260581-Reviews-Sky_Dome_Bar-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
# [进度] 89/90
#   ❌ 最终失败：外婆家(南京西路店分店) - HTTPSConnectionPool(host='cn.tripadvisor.com', port=443): Max retries exceeded with url: /Restaurant_Review-g308272-d3618706-Reviews-The_Grandma_s_Nanjing_West_Road-Shanghai.html (Caused by ResponseError('too many 403 error responses'))
# [进度] 90/90
#   —— 长休 60 秒 ——
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 223
#     220     print(f"✅ 本轮完成：新增 {completed} 条，累计 {len(df)} 条；失败见 {FAILURES_FILE}")
#     222 if __name__ == "__main__":
# --> 223     main()
#
# Cell In[2], line 214, in main()
#     212         if completed % 30 == 0:
#     213             print("  —— 长休 60 秒 ——")
# --> 214             time.sleep(60)
#     216 # 最后再去重一次
#     217 df = pd.read_csv(OUTPUT_FILE, encoding='utf-8-sig', dtype=str)
#
# KeyboardInterrupt:

# %% [markdown]
# ### <span style="color: blue;">3.简单数据处理</span>
# <p style="text-indent:2em;">
# 通过<strong>"过程介绍"</strong>中的分析，我们最终还是采用了阶段2中获取的1939条数据，并且进行了简单处理：首先除去所有不包括地址、评分、评价数中任意一个的餐厅，其次在剩下的餐厅中没有人均和类别的都标注上“未注明”，最终获得了1504条数据，保存在tripadvisor_shanghai_cleaned.csv.xlsx中。
# </p>

# %%
import pandas as pd

# 1. 读取原始 CSV
df = pd.read_excel('tripadvisor_shanghai_fixed.csv.xlsx')

# 2. 删除 “地址”、“评分”、“评价数” 任一列存在缺失值的行
df = df.dropna(subset=['地址', '评分', '评价数'])

# 3. 对 “类别” 和 “人均” 列的缺失值填充 “未注明”
df['类别'] = df['类别'].fillna('未注明')
df['人均'] = df['人均'].fillna('未注明')

# 4. 保存清洗后的结果
df.to_excel('tripadvisor_shanghai_fixed_cleaned.csv.xlsx', index=False)
